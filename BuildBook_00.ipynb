# %% [markdown]
# Import Data packages : Numpy @ Pandas

# %%
# Handeling dataframes
import pandas as pd

# Several array functions
import numpy as np

# Deal with pakages updates
import importlib

# %% [markdown]
# Get data from Coinbase pro API

# %%
# Get data from api
import requests

# Get some orderbook data from coinbase
cb_data = requests.get("https://api.pro.coinbase.com/products/BTC-USD/book?level=2").json()

# %% [markdown]
# Process Orderbook Level 2 Snapshot Data
#
# _WARNING : For Coinbase Level 2 Data Only_

# %%
import LOB_Lib
importlib.reload(LOB_Lib)
LOB = LOB_Lib.LimitOrderBook()
LOB.from_CBLev2(cb_data)

# %%
LOB.display(depth=5)
# Out:
#                           Time Side     Price      Size  Quantity
# 0  2023-07-29T18:42:07.087675Z  Ask  29306.18  0.800770         3
# 1  2023-07-29T18:42:07.087675Z  Ask  29306.19  0.380870         1
# 2  2023-07-29T18:42:07.087675Z  Ask  29306.20  0.051184         1
# 3  2023-07-29T18:42:07.087675Z  Ask  29306.29  0.005113         1
# 4  2023-07-29T18:42:07.087675Z  Ask  29306.30  0.005113         1
#                           Time Side     Price      Size  Quantity
# 0  2023-07-29T18:42:07.087675Z  Bid  29306.17  0.110122         3
# 1  2023-07-29T18:42:07.087675Z  Bid  29304.96  0.003412         1
# 2  2023-07-29T18:42:07.087675Z  Bid  29304.92  0.017061         1
# 3  2023-07-29T18:42:07.087675Z  Bid  29304.91  0.034123         1
# 4  2023-07-29T18:42:07.087675Z  Bid  29304.89  0.013281         2
